# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

from sklearn.linear_model import Perceptron
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
blobs, labels = make_blobs(n_samples=100000, centers=2, cluster_std=2.5)

# %%
print(blobs[:][:10])
print()
print(labels[:10])
# Out:
# [[ -4.03882555   8.05058453]
#  [ -6.51007497   6.51186544]
#  [ -2.54132729  12.57515758]
#  [ -4.10602948   8.10540204]
#  [  2.9836419    8.75076131]
#  [ -6.1448599    9.86902251]
#  [ -7.18890716  11.01411395]
#  [-10.43850797  13.99318889]
#  [ -4.70387093  13.56313191]
#  [ -1.18400874   7.60480637]]
#
# [0 1 1 1 0 1 1 1 1 0]

# %%
plt.scatter(blobs[:,0], blobs[:,1])

# %% [markdown]
# We are going to split our blobs & labels into random train and test subsets

# %%
blobs_train, blobs_test, labels_train, labels_test = train_test_split(blobs, labels, train_size = 0.3)
labels_train.shape
# Out:
# (30000,)

# %% [markdown]
# Now, to continue with the model

# %%
perceptron = Perceptron()
perceptron.fit(blobs_train, labels_train)
# Out:
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       n_iter=5, n_jobs=1, penalty=None, random_state=0, shuffle=True,
#       verbose=0, warm_start=False)

# %% [markdown]
# Checking the accuracy / score of the data for test and train

# %%
perceptron.score(blobs_test, labels_test)
# Out:
# 0.89777142857142855

# %%
perceptron.score(blobs_train, labels_train)
# Out:
# 0.89680000000000004

# %% [markdown]
# Predict class labels for blobs_test

# %%
predict_blobs_test = perceptron.predict(blobs_test)

# %%
confusion_matrix(labels_test, predict_blobs_test)
# Out:
# array([[32513,  2461],
#        [ 4695, 30331]])
